# %%
import pyspark
import pyspark.sql.functions as F

# %%
spark = pyspark.sql.SparkSession.builder.appName('no_pandas').getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# c:\Users\igorp\Desktop\portfolio\pyspark-basics\src\01.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/igorp/Desktop/portfolio/pyspark-basics/src/01.ipynb#ch0000001?line=0'>1</a> spark = pyspark.sql.SparkSession.builder.appName('no_pandas').getOrCreate()
#
# File c:\Users\igorp\anaconda3\lib\site-packages\pyspark\sql\session.py:228, in SparkSession.Builder.getOrCreate(self)
#     226         sparkConf.set(key, value)
#     227     # This SparkContext may be an existing one.
# --> 228     sc = SparkContext.getOrCreate(sparkConf)
#     229 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     230 # by all sessions.
#     231 session = SparkSession(sc)
#
# File c:\Users\igorp\anaconda3\lib\site-packages\pyspark\context.py:384, in SparkContext.getOrCreate(cls, conf)
# ...

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\igorp\anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2020.07                  py38_0
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# _py-xgboost-mutex         2.0                       cpu_0
# abseil-cpp                20210324.1           h0e60522_0    conda-forge
# alabaster                 0.7.12             pyhd3eb1b0_0
# altair                    4.1.0                      py_1
# anaconda                  custom                   py38_1
# anaconda-client           1.10.0           py38haa95532_0
# anaconda-navigator        2.2.0            py38haa95532_0
# anaconda-project          0.10.2             pyhd3eb1b0_0
# ansi2html                 1.5.2            py38haa95532_0
# anyio                     3.5.0            py38haa95532_0
# appdirs                   1.4.4              pyhd3eb1b0_0
# argh                      0.26.2                   py38_0
# ...
